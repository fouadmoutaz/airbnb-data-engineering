# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import gzip
import pyodbc

# %% [markdown]
# # Reading From gz File
# ## and importing data to pandas dataframe

# %%
def read_csv_from_gz(gz_file_path, encoding='utf-8'):
    '''
    Read a csv file from a gz file
    ,param: gz_file_path: path to the gz file
    encoding: encoding of the csv file, default is 'utf-8'
    ,return: a pandas dataframe
    '''
    with gzip.open(gz_file_path, 'rt', encoding=encoding) as gz_file:  
        df = pd.read_csv(gz_file)
        return df

df_calender = read_csv_from_gz('calendar.csv.gz')
df_reviews = read_csv_from_gz('reviews.csv.gz', encoding='utf-8')  
df_listings = read_csv_from_gz('listings.csv.gz', encoding='utf-8')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12184\1902009627.py:9: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(gz_file)

# %% [markdown]
# ### checking dataframes

# %%
df_reviews.head()
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0       17475   63134  2010-07-10       141807        Zoltan
# 1       17475   83802  2010-08-24        68687          John
# 2       17475   98998  2010-09-17        96055      Xiaoyang
# 3       17475  105280  2010-09-26       171084           Amy
# 4       17475  109755  2010-10-02        31238          Mike
#
#                                             comments
# 0  Excellent host, beautiful apartment, great loc...
# 1  Luca is very personable, and the views are exa...
# 2  I am glad we found Luca's apt for our stay in ...
# 3  I should start by saying we really did not wan...
# 4  Luca was a very gracious host and took efforts...

# %%
len(df_reviews)
# Out:
# 803638

# %%
df_calender.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0      198958  2023-12-14         t  $190.00            NaN               2
# 1      198958  2023-12-15         t  $190.00            NaN               2
# 2      198958  2023-12-16         t  $190.00            NaN               2
# 3      198958  2023-12-17         t  $190.00            NaN               2
# 4      198958  2023-12-18         t  $190.00            NaN               2
#
#    maximum_nights
# 0             365
# 1             365
# 2             365
# 3             365
# 4             365

# %% [markdown]
# ## see if adjusted_price is important ?

# %%
df_calender[(df_calender['price'] != df_calender['adjusted_price']) & (~df_calender["adjusted_price"].isnull())].count()
# Out:
# listing_id        0
# date              0
# available         0
# price             0
# adjusted_price    0
# minimum_nights    0
# maximum_nights    0
# dtype: int64

# %%
df_calender = df_calender.drop('adjusted_price',axis=1)

# %%
df_calender.head()
# Out:
#    listing_id        date available    price  minimum_nights  maximum_nights
# 0      198958  2023-12-14         t  $190.00               2             365
# 1      198958  2023-12-15         t  $190.00               2             365
# 2      198958  2023-12-16         t  $190.00               2             365
# 3      198958  2023-12-17         t  $190.00               2             365
# 4      198958  2023-12-18         t  $190.00               2             365

# %%
df_listings.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   17475   https://www.airbnb.com/rooms/17475  20231213195414   2023-12-14
# 1   18674   https://www.airbnb.com/rooms/18674  20231213195414   2023-12-14
# 2  198958  https://www.airbnb.com/rooms/198958  20231213195414   2023-12-14
# 3  199794  https://www.airbnb.com/rooms/199794  20231213195414   2023-12-14
# 4   23197   https://www.airbnb.com/rooms/23197  20231213195414   2023-12-14
#
#         source                                               name  \
# 0  city scrape  Rental unit in 08013 Barcelona · ★4.40 · 1 bed...
# 1  city scrape  Rental unit in Barcelona · ★4.33 · 3 bedrooms ...
# 2  city scrape  Rental unit in Barcelona · ★4.69 · 4 bedrooms ...
# 3  city scrape  Rental unit in Barcelona · ★4.80 · 1 bedroom ·...
# 4  city scrape  Rental unit in Sant Adria de Besos · ★4.77 · 3...
#
#    description                              neighborhood_overview  \
# 0          NaN                                                NaN
# 1          NaN  Apartment in Barcelona located in the heart of...
# 2          NaN  The Illa del Llac complex is a calm, relaxing ...
# 3          NaN  The apartment is located in a very safe area a...
# 4          NaN  Strategically located in the Parc del Fòrum, a...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/f6e6718f-dba0...    65623  ...
# 1  https://a0.muscache.com/pictures/13031453/413c...    71615  ...
# 2  https://a0.muscache.com/pictures/2977a5e1-e7e4...   971768  ...
# 3  https://a0.muscache.com/pictures/21904425/cbb2...   440825  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...    90417  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.68                   4.84                4.47
# 1                        4.67                   4.77                4.28
# 2                        4.87                   4.80                4.67
# 3                        4.92                   4.89                4.80
# 4                        4.97                   4.59                4.64
#
#        license instant_bookable calculated_host_listings_count  \
# 0          NaN                f                              1
# 1  HUTB-002062                t                             30
# 2  HUTB-000926                f                              9
# 3       Exempt                f                              1
# 4   HUTB005057                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                          30
# 2                                           9
# 3                                           0
# 4                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.16
# 1                                           0              0.31
# 2                                           0              0.74
# 3                                           0              1.34
# 4                                           0              0.48
#
# [5 rows x 75 columns]

# %% [markdown]
# ## checking date data types in calendar and reviews tables

# %%
df_reviews.head()
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0       17475   63134  2010-07-10       141807        Zoltan
# 1       17475   83802  2010-08-24        68687          John
# 2       17475   98998  2010-09-17        96055      Xiaoyang
# 3       17475  105280  2010-09-26       171084           Amy
# 4       17475  109755  2010-10-02        31238          Mike
#
#                                             comments
# 0  Excellent host, beautiful apartment, great loc...
# 1  Luca is very personable, and the views are exa...
# 2  I am glad we found Luca's apt for our stay in ...
# 3  I should start by saying we really did not wan...
# 4  Luca was a very gracious host and took efforts...

# %%
df_calender['date'] = pd.to_datetime(df_calender['date'])

# %%
df_reviews['date'] = pd.to_datetime(df_reviews['date'])

# %%
print(df_calender.dtypes)
# Out:
# listing_id                 int64
# date              datetime64[ns]
# available                 object
# price                     object
# minimum_nights             int64
# maximum_nights             int64
# dtype: object

# %%
print(df_reviews.dtypes)
# Out:
# listing_id                int64
# id                        int64
# date             datetime64[ns]
# reviewer_id               int64
# reviewer_name            object
# comments                 object
# dtype: object

# %% [markdown]
# ## creating date dimention

# %%
min_date = min(df_calender['date'].min() , df_reviews['date'].min())
max_date = max(df_calender['date'].max() , df_reviews['date'].max())

# %%
date_range = pd.date_range(start=min_date , end=max_date)
date_dim_df = pd.DataFrame(date_range , columns = ["date"])

# %%
date_dim_df.head()
# Out:
#         date
# 0 2010-07-10
# 1 2010-07-11
# 2 2010-07-12
# 3 2010-07-13
# 4 2010-07-14

# %%
date_dim_df["year"] = date_dim_df["date"].dt.year
date_dim_df["month"] = date_dim_df["date"].dt.month
date_dim_df["day"] = date_dim_df["date"].dt.day
date_dim_df["quarter"] = date_dim_df["date"].dt.quarter
date_dim_df["season"] = (date_dim_df["date"].dt.month % 12 + 3) //3
date_dim_df["date_key"]=date_dim_df["date"].astype('string').str.replace('-','')

# %%
date_dim_df.head()
# Out:
#         date  year  month  day  quarter  season  date_key
# 0 2010-07-10  2010      7   10        3       3  20100710
# 1 2010-07-11  2010      7   11        3       3  20100711
# 2 2010-07-12  2010      7   12        3       3  20100712
# 3 2010-07-13  2010      7   13        3       3  20100713
# 4 2010-07-14  2010      7   14        3       3  20100714

# %% [markdown]
# ## making of a date key for relationships between date dimention table and other tables containg date

# %%
df_calender['date_key'] = df_calender['date'].astype('string').str.replace('-', '')
df_calender.head()
# Out:
#    listing_id       date available    price  minimum_nights  maximum_nights  \
# 0      198958 2023-12-14         t  $190.00               2             365
# 1      198958 2023-12-15         t  $190.00               2             365
# 2      198958 2023-12-16         t  $190.00               2             365
# 3      198958 2023-12-17         t  $190.00               2             365
# 4      198958 2023-12-18         t  $190.00               2             365
#
#    date_key
# 0  20231214
# 1  20231215
# 2  20231216
# 3  20231217
# 4  20231218

# %%
df_calender['price']=df_calender['price'].str.replace('$','').str.replace(',','').astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df_calender['price']=df_calender['price'].str.replace('$','').str.replace(',','').astype('float')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6296, in NDFrame.__getattr__(self, name)
#    6289 if (
#    6290     name not in self._internal_names_set
#    6291     and name not in self._metadata
#    6292     and name not in self._accessors
#    6293     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294 ):
#    6295     return self[name]
# -> 6296 return object.__getattribute__(self, name)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:191, in StringMethods.__init__(self, data)
#     188 def __init__(self, data) -> None:
#     189     from pandas.core.arrays.string_ import StringDtype
# --> 191     self._inferred_dtype = self._validate(data)
#     192     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\strings\accessor.py:245, in StringMethods._validate(data)
#     242 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     244 if inferred_dtype not in allowed_types:
# --> 245     raise AttributeError("Can only use .str accessor with string values!")
#     246 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df_calender.dtypes
# Out:
# listing_id                 int64
# date              datetime64[ns]
# available                 object
# price                    float64
# minimum_nights             int64
# maximum_nights             int64
# date_key          string[python]
# dtype: object

# %%
df_reviews['date'] = pd.to_datetime(df_reviews['date']) 
df_reviews['date_key'] = df_reviews['date'].astype('string').str.replace('-','')
df_reviews.rename(columns = {'id':'review_id'}, inplace=True)

# %%
df_reviews.head()
# Out:
#    listing_id  review_id       date  reviewer_id reviewer_name  \
# 0       17475      63134 2010-07-10       141807        Zoltan
# 1       17475      83802 2010-08-24        68687          John
# 2       17475      98998 2010-09-17        96055      Xiaoyang
# 3       17475     105280 2010-09-26       171084           Amy
# 4       17475     109755 2010-10-02        31238          Mike
#
#                                             comments  date_key
# 0  Excellent host, beautiful apartment, great loc...  20100710
# 1  Luca is very personable, and the views are exa...  20100824
# 2  I am glad we found Luca's apt for our stay in ...  20100917
# 3  I should start by saying we really did not wan...  20100926
# 4  Luca was a very gracious host and took efforts...  20101002

# %%
df_listings.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   17475   https://www.airbnb.com/rooms/17475  20231213195414   2023-12-14
# 1   18674   https://www.airbnb.com/rooms/18674  20231213195414   2023-12-14
# 2  198958  https://www.airbnb.com/rooms/198958  20231213195414   2023-12-14
# 3  199794  https://www.airbnb.com/rooms/199794  20231213195414   2023-12-14
# 4   23197   https://www.airbnb.com/rooms/23197  20231213195414   2023-12-14
#
#         source                                               name  \
# 0  city scrape  Rental unit in 08013 Barcelona · ★4.40 · 1 bed...
# 1  city scrape  Rental unit in Barcelona · ★4.33 · 3 bedrooms ...
# 2  city scrape  Rental unit in Barcelona · ★4.69 · 4 bedrooms ...
# 3  city scrape  Rental unit in Barcelona · ★4.80 · 1 bedroom ·...
# 4  city scrape  Rental unit in Sant Adria de Besos · ★4.77 · 3...
#
#    description                              neighborhood_overview  \
# 0          NaN                                                NaN
# 1          NaN  Apartment in Barcelona located in the heart of...
# 2          NaN  The Illa del Llac complex is a calm, relaxing ...
# 3          NaN  The apartment is located in a very safe area a...
# 4          NaN  Strategically located in the Parc del Fòrum, a...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/f6e6718f-dba0...    65623  ...
# 1  https://a0.muscache.com/pictures/13031453/413c...    71615  ...
# 2  https://a0.muscache.com/pictures/2977a5e1-e7e4...   971768  ...
# 3  https://a0.muscache.com/pictures/21904425/cbb2...   440825  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...    90417  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.68                   4.84                4.47
# 1                        4.67                   4.77                4.28
# 2                        4.87                   4.80                4.67
# 3                        4.92                   4.89                4.80
# 4                        4.97                   4.59                4.64
#
#        license instant_bookable calculated_host_listings_count  \
# 0          NaN                f                              1
# 1  HUTB-002062                t                             30
# 2  HUTB-000926                f                              9
# 3       Exempt                f                              1
# 4   HUTB005057                f                              2
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                          30
# 2                                           9
# 3                                           0
# 4                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.16
# 1                                           0              0.31
# 2                                           0              0.74
# 3                                           0              1.34
# 4                                           0              0.48
#
# [5 rows x 75 columns]

# %% [markdown]
# ## removing unnecessary columns

# %%
df_listings = df_listings.drop(columns=['listing_url', 'scrape_id', 'last_scraped', 'source', 'description', 'picture_url'] , axis=1)

# %%
df_listings.head()
# Out:
#        id                                               name  \
# 0   17475  Rental unit in 08013 Barcelona · ★4.40 · 1 bed...
# 1   18674  Rental unit in Barcelona · ★4.33 · 3 bedrooms ...
# 2  198958  Rental unit in Barcelona · ★4.69 · 4 bedrooms ...
# 3  199794  Rental unit in Barcelona · ★4.80 · 1 bedroom ·...
# 4   23197  Rental unit in Sant Adria de Besos · ★4.77 · 3...
#
#                                neighborhood_overview  host_id  \
# 0                                                NaN    65623
# 1  Apartment in Barcelona located in the heart of...    71615
# 2  The Illa del Llac complex is a calm, relaxing ...   971768
# 3  The apartment is located in a very safe area a...   440825
# 4  Strategically located in the Parc del Fòrum, a...    90417
#
#                                    host_url       host_name  host_since  \
# 0   https://www.airbnb.com/users/show/65623            Luca  2009-12-25
# 1   https://www.airbnb.com/users/show/71615   Mireia  Maria  2010-01-19
# 2  https://www.airbnb.com/users/show/971768           Laura  2011-08-15
# 3  https://www.airbnb.com/users/show/440825          Teresa  2011-03-14
# 4   https://www.airbnb.com/users/show/90417  Etain (Marnie)  2010-03-09
#
#       host_location                                         host_about  \
# 0       Rome, Italy                                          Italian.
# 1  Barcelona, Spain  We are Mireia (47) & Maria (49), two multiling...
# 2  Barcelona, Spain  Owner and manager of apartments in Barcelona. ...
# 3  Barcelona, Spain  I live in Barcelona since 1996 and  work in an...
# 4  Catalonia, Spain  Hi there, I'm marnie from Australia, though I ...
#
#    host_response_time  ... review_scores_communication review_scores_location  \
# 0      within an hour  ...                        4.68                   4.84
# 1      within an hour  ...                        4.67                   4.77
# 2      within an hour  ...                        4.87                   4.80
# 3  within a few hours  ...                        4.92                   4.89
# 4      within an hour  ...                        4.97                   4.59
#
#   review_scores_value      license instant_bookable  \
# 0                4.47          NaN                f
# 1                4.28  HUTB-002062                t
# 2                4.67  HUTB-000926                f
# 3                4.80       Exempt                f
# 4                4.64   HUTB005057                f
#
#   calculated_host_listings_count  calculated_host_listings_count_entire_homes  \
# 0                              1                                            1
# 1                             30                                           30
# 2                              9                                            9
# 3                              1                                            0
# 4                              2                                            2
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             1
# 4                                             0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.16
# 1                                           0              0.31
# 2                                           0              0.74
# 3                                           0              1.34
# 4                                           0              0.48
#
# [5 rows x 69 columns]

# %%
df_listings.rename(columns={'id':'listing_id'},inplace =True)
df_listings.head()
# Out:
#    listing_id                                               name  \
# 0       17475  Rental unit in 08013 Barcelona · ★4.40 · 1 bed...
# 1       18674  Rental unit in Barcelona · ★4.33 · 3 bedrooms ...
# 2      198958  Rental unit in Barcelona · ★4.69 · 4 bedrooms ...
# 3      199794  Rental unit in Barcelona · ★4.80 · 1 bedroom ·...
# 4       23197  Rental unit in Sant Adria de Besos · ★4.77 · 3...
#
#                                neighborhood_overview  host_id  \
# 0                                                NaN    65623
# 1  Apartment in Barcelona located in the heart of...    71615
# 2  The Illa del Llac complex is a calm, relaxing ...   971768
# 3  The apartment is located in a very safe area a...   440825
# 4  Strategically located in the Parc del Fòrum, a...    90417
#
#                                    host_url       host_name  host_since  \
# 0   https://www.airbnb.com/users/show/65623            Luca  2009-12-25
# 1   https://www.airbnb.com/users/show/71615   Mireia  Maria  2010-01-19
# 2  https://www.airbnb.com/users/show/971768           Laura  2011-08-15
# 3  https://www.airbnb.com/users/show/440825          Teresa  2011-03-14
# 4   https://www.airbnb.com/users/show/90417  Etain (Marnie)  2010-03-09
#
#       host_location                                         host_about  \
# 0       Rome, Italy                                          Italian.
# 1  Barcelona, Spain  We are Mireia (47) & Maria (49), two multiling...
# 2  Barcelona, Spain  Owner and manager of apartments in Barcelona. ...
# 3  Barcelona, Spain  I live in Barcelona since 1996 and  work in an...
# 4  Catalonia, Spain  Hi there, I'm marnie from Australia, though I ...
#
#    host_response_time  ... review_scores_communication review_scores_location  \
# 0      within an hour  ...                        4.68                   4.84
# 1      within an hour  ...                        4.67                   4.77
# 2      within an hour  ...                        4.87                   4.80
# 3  within a few hours  ...                        4.92                   4.89
# 4      within an hour  ...                        4.97                   4.59
#
#   review_scores_value      license instant_bookable  \
# 0                4.47          NaN                f
# 1                4.28  HUTB-002062                t
# 2                4.67  HUTB-000926                f
# 3                4.80       Exempt                f
# 4                4.64   HUTB005057                f
#
#   calculated_host_listings_count  calculated_host_listings_count_entire_homes  \
# 0                              1                                            1
# 1                             30                                           30
# 2                              9                                            9
# 3                              1                                            0
# 4                              2                                            2
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             1
# 4                                             0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.16
# 1                                           0              0.31
# 2                                           0              0.74
# 3                                           0              1.34
# 4                                           0              0.48
#
# [5 rows x 69 columns]

# %% [markdown]
# # *now we upload it the sql server database*

# %%
from sqlalchemy import create_engine

# Define your SQL Server connection details
server = 'DESKTOP-HLV4EPB\SQLEXPRESS'
database = 'Airbnb_DWH'
trusted_connection = 'yes'

# Create a connection string
conn_str = f'mssql+pyodbc://{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server&Trusted_Connection={trusted_connection}'

# Create SQLAlchemy engine
engine = create_engine(conn_str)

# Upload DataFrames to SQL Server
try:
    # Upload DataFrames
    date_dim_df.to_sql('date_Dim', engine, if_exists='replace', index=False)
    print('date uploaded')
    df_listings.to_sql('listing_Dim', engine, if_exists='replace', index=False)
    print('listing uploaded')
    df_calender.to_sql('calendar_Fact', engine, if_exists='replace', index=False)
    print('calendar uploaded')
    df_reviews.to_sql('review_Fact', engine, if_exists='replace', index=False)
    print('review uploaded')
    print("DataFrames uploaded successfully to SQL Server.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
finally:
    # Dispose of the engine
    engine.dispose()
# Out:
# date uploaded
# listing uploaded
# calendar uploaded
# review uploaded
# DataFrames uploaded successfully to SQL Server.
